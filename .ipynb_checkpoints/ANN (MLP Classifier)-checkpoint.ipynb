# %%
import glob
import pandas as pd
import numpy as np
import os

# %%
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import time
import re 

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import confusion_matrix
import joblib

# %%
# all_file= glob.glob("../Data/*.xlsx")
all_file = glob.glob("./songData/*.xlsx")
len(all_file)
# Out:
# 21

# %% [markdown]
# # Preprocessing steps

# %%
names = []
count = []
clusters = []
data = []

for each in all_file:
    temp = pd.read_excel(each)
    
    
    count.append(len(temp))
    
    names.append(each.split('/')[2][:-5])
    clusters.append(temp['songType'].iloc[1])
#     names.append(each.split('/')[1][:-5])
#     clusters.append(temp['idx'].iloc[4])
    
    
    data.append(temp)
    
cluster_ids =clusters

# %%
data = pd.concat(data)
data = data.sample(frac = 1)

data
# Out:
#      Unnamed: 0                                             lyrics  songType
# 36         3429  এস হে অপারের কান্ডারি । পড়েছি অকূল পাথারে দাও...        19
# 364        2402  [জীবন সুন্দর। আকাশ, বাতাস, পাহাড় সমুদ্র সবুজ ব...        13
# 149         636  খেলবো হোলি রঙ দেব না। তাই কখনো হয়? খেলবো হোলি ...         3
# 96          512  আলপনা তুমি মোরে ভুলে গেছ জানি আর কোনদিন ফিরে প...        13
# 550        3257  হাসতে দেখ গাইতে দেখ অনেক কথায় মুখর আমায় দেখ ...        13
# ..          ...                                                ...       ...
# 57          457  দিনের শেষে নীড়ের টানে মন যদি কাঁদে দিনের শেষে...        13
# 638        2333  তুমি রবে নীরবে হৃদয়ে মম নিবিড় নিভৃত পূর্ণিমানি...        17
# 215        1379  এই কোলাহল এই লোকালয় এত প্রিয়জন কেউ কারো নয় ...        13
# 47         1653  আইল ঋতুরাজ সজনি, জ্যোত্স্না‌ময়  মধুর রজনি, বি...        14
# 25          226  এসো গো জ্বেলে দিয়ে যাও প্রদীপখানি        বিজন...        17
#
# [4105 rows x 3 columns]

# %% [markdown]
# ### Removing  Stopwords  from body if exists

# %%
# stopwords = [ 'হাই', 'ফ্রিকুয়েন্সি', 'কিন্তু', 'অপ্রয়োজনীয়', 'শব্দ' ]
stopwords = ['হাই', 'ফ্রিকুয়েন্সি', 'কিন্তু', 'অপ্রয়োজনীয়', 'শব্দ', 'অবশ্য',
'অনেক',
'অনেকে',
'অনেকেই',
'অন্তত',
'অথবা',
'অথচ',
'অর্থাত',
'অন্য',
'আজ',
'আছে',
'আপনার',
'আপনি',
'আবার',
'আমরা',
'আমাকে',
'আমাদের',
'আমার',
'আমি',
'আরও',
'আর',
'আগে',
'আগেই',
'আই',
'অতএব',
'আগামী',
'অবধি',
'অনুযায়ী',
'আদ্যভাগে',
'এই',
'একই',
'একে',
'একটি',
'এখন',
'এখনও',
'এখানে',
'এখানেই',
'এটি',
'এটা',
'এটাই',
'এতটাই',
'এবং',
'একবার',
'এবার',
'এদের',
'এঁদের',
'এমন',
'এমনকী',
'এল',
'এর',
'এরা',
'এঁরা',
'এস',
'এত',
'এতে',
'এসে',
'একে',
'এ',
'ঐ',
 'ই',
'ইহা',
'ইত্যাদি',
'উনি',
'উপর',
'উপরে',
'উচিত',
'ও',
'ওই',
'ওর',
'ওরা',
'ওঁর',
'ওঁরা',
'ওকে',
'ওদের',
'ওঁদের',
'ওখানে',
'কত',
'কবে',
'করতে',
'কয়েক',
'কয়েকটি',
'করবে',
'করলেন',
'করার',
'কাছে',
'কাজে',
'কারণ',
'কিছু',
'কিছুই',
'কিন্তু',
'কিংবা',
'কি',
'কী',
'কেন',
'কে',
'কোনও',
'কোনো',
'ক্ষেত্রে',
'খুব',
'গুলি'
'গিয়ে',
'গোটা',
'চলে',
'ছাড়া',
'ছাড়াও',
'ছিলেন',
'ছিল',
'জন্য',
'জানা',
'ঠিক',
'তিনি',
'তিনঐ',
'তিনিও',
'তেমন',
'তাকে',
'তাহা',
'তাহাতে',
'তাহার',
'তাদের',
'তিনি',
'তা',
'তুমি',
'তোমার',
'তথা',
'না',
'পারে',
'ব্যবহার',
'বললেন',
'যখন',
'যদি',
'টি' ]

# %%
data['lyrics'] = data['lyrics'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
# data['content'] = data['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %%
X_train, X_test, y_train, y_test =  train_test_split(data['lyrics'], data['songType'], test_size=0.33, random_state=42 )
# X_train, X_test, y_train, y_test =  train_test_split(data['content'], data['idx'], test_size=0.33, random_state=42 )

# %%
X_train.shape
# Out:
# (2750,)

# %%
X_test.shape
# Out:
# (1355,)

# %% [markdown]
# ### Classification report

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn import metrics

total_data_count = len(data)
per_class_counts = []
# unique_classes = np.unique(data['idx'].values)
unique_classes = np.unique(data['songType'].values)

class_count_mean = np.mean(count)

###########################3
############### classifier setup ################

from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([
    
    ('vect', CountVectorizer(stop_words=stopwords,
                            analyzer="word", 
                            lowercase=False,
                            token_pattern="[\S]*",
                            tokenizer=None,
                            ngram_range=(1, 3),
                            preprocessor=None)),                 
    ('tfidf', TfidfTransformer()),
    ('clf-svm', DecisionTreeClassifier(random_state=0)),
                                                                        
])
classifier = text_clf_svm.fit(list(X_train), list(y_train))


cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=0)
score = cross_val_score(text_clf_svm, list(X_train), list(y_train), cv=cv)

print("Cross Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))


predicted = classifier.predict(X_test)
# Out:
# /home/pulock46/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# /home/pulock46/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# /home/pulock46/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# /home/pulock46/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# /home/pulock46/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# /home/pulock46/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Cross Accuracy: 0.33 (+/- 0.04)

# %%
#

# %%
# joblib.dump(classifier, '../Model/sample_model.pickle')

# %%
print("Cross Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print(metrics.classification_report(y_test, predicted))
# Out:
# Cross Accuracy: 0.33 (+/- 0.04)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.35      0.38      0.36       338
#            2       0.00      0.00      0.00         3
#            3       0.31      0.30      0.30       267
#            4       0.00      0.00      0.00         1
#            5       0.02      0.06      0.03        16
#            6       0.12      0.14      0.13        22
#            7       0.24      0.29      0.26        55
#            8       0.00      0.00      0.00         4
#            9       0.07      0.08      0.07        12
#           10       0.00      0.00      0.00        14
#           11       0.08      0.05      0.06        22
#           12       0.06      0.04      0.04        55
#           13       0.29      0.32      0.31       221
#           14       0.00      0.00      0.00        19
#           16       0.00      0.00      0.00         2
#           17       0.60      0.52      0.56       280
#           18       0.00      0.00      0.00         4
#           19       0.62      0.71      0.67        14
#           20       1.00      0.50      0.67         2
#
#     accuracy                           0.34      1355
#    macro avg       0.19      0.17      0.17      1355
# weighted avg       0.34      0.34      0.34      1355
# /home/pulock46/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd
confusion_matrix = list(metrics.confusion_matrix(y_test, predicted))

print(len(confusion_matrix), len(confusion_matrix[0]))
print(len(names), len(names[0]))
# Out:
# 20 20
# 21 10

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = confusion_matrix
# df_cm = pd.DataFrame(array, index = [i for i in names],
#               columns = [i for i in names])
df_cm = pd.DataFrame(array)
df_norm_col=(df_cm-df_cm.mean())/df_cm.std()
#df_norm_col=df_cm-df_cm.mean()
plt.figure(figsize = (10,7))
sn.heatmap(df_norm_col, annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>
