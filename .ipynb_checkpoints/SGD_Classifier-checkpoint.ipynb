# %%
import glob
import pandas as pd
import numpy as np
import os

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import time
import re 

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import confusion_matrix
import joblib

# %%
# all_file= glob.glob("../Data/*.xlsx")
all_file = glob.glob("./songData/*.xlsx")
len(all_file)
# Out:
# 21

# %% [markdown]
# # Preprocessing steps

# %%
names = []
count = []
clusters = []
data = []

for each in all_file:
    temp = pd.read_excel(each)
    
    
    count.append(len(temp))
    
    names.append(each.split('/')[2][:-5])
    clusters.append(temp['songType'].iloc[1])
#     names.append(each.split('/')[1][:-5])
#     clusters.append(temp['idx'].iloc[4])
    
    
    data.append(temp)
    
cluster_ids =clusters

# %%
data = pd.concat(data)
data = data.sample(frac = 1)

data
# Out:
#      Unnamed: 0                                             lyrics  songType
# 640        2335  না সজনী, না, আমি জানি জানি, সে আসিবে না। এমনি ...        17
# 76          159  মেয়ে= আমি তো পারি না,আর তো পারি না, মনের বুঝা ...         3
# 121        3692  ও শ্যাম রে তোমার সনে একেলা পাইয়াছি রে শ্যাম এই...        12
# 22          970  তোমার লাগি কান্দিয়া, থাকি নিশি জাগিয়া চাওরে ...        12
# 33           88  নয়ন যে মোর বারণ মানে না। বারণ মানে না মন কাঁদ...         7
# ..          ...                                                ...       ...
# 416        1823  কাজল নদীর জলে, ভরা ঢেউ ছল ছলে, প্রদীপ ভাসাও কা...         1
# 631        3516  আমার জীবনের এত খুশি এত হাসি আজ কোথায় গেল ফুলে...         3
# 545        3098  প্রেম যেন মোর গোধুলি বেলার পান্থ পাখির কাকলি। ...         3
# 669        2831  যায় দিন, দিন যায়, কাটে বছর, অধরা ভালোবাসা, কতন...         1
# 265         873  কুহুর কবিতা পৃথিবী যে ওই শোনে বনের ফাগুন  জেগে...         1
#
# [4105 rows x 3 columns]

# %% [markdown]
# ### Removing  Stopwords  from body if exists

# %%
stopwords = [ 'হাই', 'ফ্রিকুয়েন্সি', 'কিন্তু', 'অপ্রয়োজনীয়', 'শব্দ' ]

# %%
data['content'] = data['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %%
X_train, X_test, y_train, y_test =  train_test_split(data['content'], data['idx'], test_size=0.33, random_state=42 )

# %%
X_train.shape
# Out:
# (13400,)

# %%
X_test.shape
# Out:
# (6600,)

# %% [markdown]
# ### Classification report

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn import metrics

total_data_count = len(data)
per_class_counts = []
unique_classes = np.unique(data['idx'].values)
class_count_mean = np.mean(count)

###########################3
############### classifier setup ################

from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([
    
    ('vect', CountVectorizer(stop_words=stopwords,
                            analyzer="word", 
                            lowercase=False,
                            token_pattern="[\S]*",
                            tokenizer=None,
                            ngram_range=(1, 3),
                            preprocessor=None)),                 
    ('tfidf', TfidfTransformer()),
    ('clf-svm', SGDClassifier(loss = 'modified_huber', penalty='l2', max_iter=100)),
                                                                        
])
classifier = text_clf_svm.fit(list(X_train), list(y_train))


cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=0)
score = cross_val_score(text_clf_svm, list(X_train), list(y_train), cv=cv)

print("Cross Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))


predicted = classifier.predict(X_test)
# Out:
# /home/pulock46/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:383: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Cross Accuracy: 0.44 (+/- 0.02)

# %%
#

# %%
# joblib.dump(classifier, '../Model/sample_model.pickle')

# %%
print("Cross Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print(metrics.classification_report(y_test, predicted))
# Out:
# Cross Accuracy: 0.44 (+/- 0.02)
#               precision    recall  f1-score   support
#
#            1       0.35      0.29      0.32       337
#            2       0.56      0.48      0.52       329
#            3       0.32      0.34      0.33       328
#            4       0.33      0.40      0.36       306
#            5       0.42      0.32      0.36       346
#            6       0.52      0.22      0.31       339
#            7       0.52      0.54      0.53       353
#            8       0.45      0.40      0.42       350
#            9       0.56      0.23      0.33       318
#           10       0.52      0.74      0.61       323
#           11       0.59      0.40      0.47       356
#           12       0.90      0.94      0.92       341
#           13       0.91      0.92      0.92       299
#           14       0.35      0.35      0.35       337
#           15       0.44      0.33      0.38       327
#           16       0.32      0.58      0.41       323
#           17       0.36      0.59      0.44       326
#           18       0.34      0.39      0.36       329
#           19       0.39      0.31      0.35       321
#           20       0.31      0.42      0.36       312
#
#     accuracy                           0.46      6600
#    macro avg       0.47      0.46      0.45      6600
# weighted avg       0.47      0.46      0.45      6600

# %%
import pandas as pd
confusion_matrix = list(metrics.confusion_matrix(y_test, predicted))

print(len(confusion_matrix), len(confusion_matrix[0]))
print(len(names), len(names[0]))
# Out:
# 20 20
# 20 0

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = confusion_matrix
df_cm = pd.DataFrame(array, index = [i for i in names],
              columns = [i for i in names])
df_norm_col=(df_cm-df_cm.mean())/df_cm.std()
#df_norm_col=df_cm-df_cm.mean()
plt.figure(figsize = (10,7))
sn.heatmap(df_norm_col, annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>
